# %%
import math
import numpy as np
import pandas as pd

# %%
d = pd.read_csv('train.csv', header=None)
#d = pd.DataFrame([d.loc[::3], d.loc[1::3], d.loc[2::3]]).T
#d

# %%
d.loc[::3].plot()

# %%
d.loc[1::3].plot()

# %%
d.loc[2::3].plot()

# %%
d.loc[3::3].plot()

# %%
x = np.linspace(0.01, 1, 100)
pd.DataFrame([-math.log(a) for a in x], x).plot()
